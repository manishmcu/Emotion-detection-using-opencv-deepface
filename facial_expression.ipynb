# %%
import cv2   ## pip install opencv-python
## pip install opencv-contrib-python -> full package

# %%
# Check this Vedio: https://youtu.be/fkgpvkqcoJc

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('happy_face.jpg')

# %%
plt.imshow(img) #BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
from deepface import DeepFace ## pip install deepface

# %%
predictions= DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 3s 3s/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:04<00:13,  4.54s/it]
# 1/1 [==============================] - 1s 522ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:05<00:04,  2.26s/it]
# 1/1 [==============================] - 0s 496ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:05<00:01,  1.48s/it]
# 1/1 [==============================] - 0s 471ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:06<00:00,  1.57s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.00012205881603222224,
#   'disgust': 1.766354315417551e-10,
#   'fear': 7.977704399309005e-05,
#   'happy': 99.96813535690308,
#   'sad': 0.00555541628273204,
#   'surprise': 0.0031414005206897855,
#   'neutral': 0.02296997408848256},
#  'dominant_emotion': 'happy',
#  'region': {'x': 154, 'y': 67, 'w': 187, 'h': 187},
#  'age': 24,
#  'gender': 'Man',
#  'race': {'asian': 0.02082446341819007,
#   'indian': 2.2094891566647106,
#   'black': 0.02073024268870143,
#   'white': 16.210294817650936,
#   'middle eastern': 74.00604200291133,
#   'latino hispanic': 7.53261655180257},
#  'dominant_race': 'middle eastern'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
face_cascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml") #Note the change

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # print(faceCascade.empty())
faces=face_cascade.detectMultiScale(gray, scaleFactor=1.1,minNeighbors=4)

        # Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
    
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font, 1,
           (0,0,255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad_face.jpg')
predictions= DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 8ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:00<00:00,  7.97it/s]
# 1/1 [==============================] - 0s 279ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:00<00:00,  3.74it/s]
# 1/1 [==============================] - 0s 292ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:00<00:00,  3.33it/s]
# 1/1 [==============================] - 0s 294ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.41it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 40.41907489299774,
#   'disgust': 0.03644709649961442,
#   'fear': 4.9211762845516205,
#   'happy': 0.0008153499038598966,
#   'sad': 46.097493171691895,
#   'surprise': 0.07319282740354538,
#   'neutral': 8.451801538467407},
#  'dominant_emotion': 'sad',
#  'region': {'x': 165, 'y': 69, 'w': 126, 'h': 126},
#  'age': 24,
#  'gender': 'Man',
#  'race': {'asian': 2.984789183412693,
#   'indian': 29.109207285548123,
#   'black': 0.7147002420217087,
#   'white': 19.34152327078858,
#   'middle eastern': 26.37568132587449,
#   'latino hispanic': 21.47410320926943},
#  'dominant_race': 'indian'}

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # print(faceCascade.empty())
faces=face_cascade.detectMultiScale(gray, scaleFactor=1.1,minNeighbors=4)

        # Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)
    
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
    
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font, 1,
           (0,0,255),
           2,
           cv2.LINE_4);
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('Excited_face.jpg')
predictions= DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:00<00:00,  4.67it/s]
# 1/1 [==============================] - 0s 285ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:00<00:00,  2.86it/s]
# 1/1 [==============================] - 0s 280ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:00<00:00,  2.93it/s]
# 1/1 [==============================] - 0s 285ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.02it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 3.193925883185445e-05,
#   'disgust': 9.485158883860245e-10,
#   'fear': 0.008452716932840536,
#   'happy': 1.2053295747167944e-07,
#   'sad': 0.00015390802226330938,
#   'surprise': 99.99136328645726,
#   'neutral': 6.837120166763959e-09},
#  'dominant_emotion': 'surprise',
#  'region': {'x': 162, 'y': 102, 'w': 271, 'h': 271},
#  'age': 25,
#  'gender': 'Man',
#  'race': {'asian': 91.99222874595098,
#   'indian': 2.046038704874438,
#   'black': 0.34956107602632497,
#   'white': 1.1843404507243902,
#   'middle eastern': 0.17600090826308182,
#   'latino hispanic': 4.251832023372175},
#  'dominant_race': 'asian'}

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # print(faceCascade.empty())
faces=face_cascade.detectMultiScale(gray, scaleFactor=1.1,minNeighbors=4)

        # Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)
    
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
    
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font, 1,
           (0,0,255),
           2,
           cv2.LINE_4);
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('neutral_face.jpg')
predictions= DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 16ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:00<00:00,  7.00it/s]
# 1/1 [==============================] - 0s 274ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:00<00:00,  3.44it/s]
# 1/1 [==============================] - 0s 271ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:00<00:00,  3.23it/s]
# 1/1 [==============================] - 0s 284ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.33it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 1.6479456797242165,
#   'disgust': 1.2157203022056251e-08,
#   'fear': 0.061284046387299895,
#   'happy': 0.001481906929257093,
#   'sad': 1.7499540001153946,
#   'surprise': 0.0006325992217171006,
#   'neutral': 96.53870463371277},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 166, 'y': 83, 'w': 179, 'h': 179},
#  'age': 27,
#  'gender': 'Man',
#  'race': {'asian': 0.041903663077391684,
#   'indian': 0.44618663378059864,
#   'black': 0.04784736083820462,
#   'white': 62.05248236656189,
#   'middle eastern': 18.87499839067459,
#   'latino hispanic': 18.536590039730072},
#  'dominant_race': 'white'}

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # print(faceCascade.empty())
faces=face_cascade.detectMultiScale(gray, scaleFactor=1.1,minNeighbors=4)

        # Draw a rectangle around the faces
for(x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)
    
font = cv2.FONT_HERSHEY_SIMPLEX

    # Use putText() method for
    # inserting text on video
    
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font, 1,
           (0,0,255),
           2,
           cv2.LINE_4);
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
